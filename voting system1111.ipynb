# %%
def Validate(inpMess, arr, mess):
    fA = input(inpMess)
    while fA not in arr:
        print(mess)
        fA = input(inpMess)
    return fA

import time
import sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
class Voting_system():
    def __init__(self):
        self.d={'160001':'1111','160002':'0011','160003':'8900','160004':'4500','160005':'1208','160006':'12345','160007':'tayo','160008':'kay','160009':'17899','160010':'bolaji'}
        self.a=list(self.d.keys())
        self.b=list(self.d.values())
        self.name=['shayo','leon','toyin','joshua','bolaji','tolani','kehinde','samuel','mubarak','lukema']
        self.countlist=[0,0,0,0]
        self.passavote=[0,0,0,0]
        self.passadatabase=['160001','160002','160003','160004','160005']
        self.fetdatabase=[0,0,0,0]
        self.department=[0,0,0,0,0,0,0,0]
        self.ballotbox=[]
    def login(self):
        print('''
              ####################################################
              ##         WELCOME TO LAUTECH VOTING SYSTEM       ##
        ####################################################################
        ''')
        self.matric =input('kindly enter your matric number:')
        while not self.matric .isnumeric() or len(self.matric)!=6 or self.matric not in self.a:
            print(' you enter an invalid matric number,kindly re-enter your 6 digit matric number:')
            self.matric =input('kindly enter your matric number:')
        while self.matric in self.ballotbox:
            print('you have already voted,kindly allow other to cast their vote')
            self.matric =input('enter your matric number,new user :')
        self.password=input('kindly enter your password:')
        self.count=0
        self.delay=3
        while self.password!=self.b[self.a.index(self.matric)]:
            for i in range(self.delay,0,-1):
                print('please wait while your account is being verify',self.delay+self.count,'secs')
            time.sleep(1)
            self.count-=1
            print('error,incorrect password,try again you have',2-self.count,'more attempt')
            self.password=input('kindly re-enter your password:') 
            self.count+=1
            if self.count>=3:
                print('you have been ban from taking part in this election ,kindly vist IcT CENTER for quick retivication')
                sys.exit()
        if self.password==self.b[self.a.index(self.matric)]:
            print('login successfully')
            print('welcome dear',self.name[self.a.index(self.matric)].upper(),'to LAUTECH ELECTION PAGE')
        def exitorcont(func):
            print('''
            press 1 for another services or 0 to exit
            ''')
            res = Validate('Enter your choice',['1','0'],'Enter a valid choice')
            if res=='1':
                func()
            elif res=='0':
                self.login()
    def vote_page(self):
        def exitorcont(func):
            print('''
            press 1 for another services or 0 to exit
            ''')
            res = Validate('Enter your choice',['1','0'],'Enter a valid choice')
            if res=='1':
                func()
            elif res=='0':
                self.login()
        print('''
              #############################################################
              ##           WELCOME TO LAUTECH SUG ELECTION VOTING PAGE   ##
              #############################################################
              ''')
        print('PRESIDENT ELECTION')
        print('''PRESS 1 0R 2 TO VOTE FOR THE CANDIDATE OF YOUR CHOOSE
                     1.ISARINADE AYODEJI FELIX(EINSTEIN)
                     2.ADEBOYE ANUOLUWAPO(ANUOLUWA)
        ''')
        res=input('pick your candiadate:')
        while res not in ['1','2']:
            print('error!!! pick either one or two')
            res=input('pick your candiadate:')
        if res=='1':
            print('you vote for EINSTEIN')
            print('press 1 to comfirm your vote and 0 to go back')
            a=input('enter your chose')
            while a not in ['1','0']:
                print('error enter either 1 or 0')
                a=input('enter your chose')
            if a=='1':
                print('you have vote for EINTEIN')
                self.countlist[0]+=1
                #print(self.countlist)
            if a=='0':
                exitorcont(self.vote_page())
        if res=='2':
            print('you vote for ANUOLUWAPO')
            print('press 1 to comfirm your vote and 0 to go back')
            a=input('enter your chose')
            while a not in ['1','0']:
                print('error enter either 1 or 0')
                a=input('enter your chose')
            if a=='1':
                print('you have vote for ANUOLUWAPO')
                self.countlist[1]+=1
                #print(self.countlist)
            if a=='0':
                exitorcont(self.vote_page())
        print(' VICE PRESIDENT ELECTION')
        print('''PRESS 1 0R 2 TO VOTE FOR THE CANDIDATE OF YOUR CHOOSE
                     1.MEG
                     2.TIOLA
        ''')
        res=input('pick your candiadate:')
        while res not in ['1','2']:
            print('error!!! pick either one or two')
            res=input('pick your candiadate:')
        if res=='1':
            print('you vote for MEG')
            print('press 1 to comfirm your vote and 0 to go back')
            a=input('enter your chose')
            while a not in ['1']:
                print('error enter either 1 or 0')
                a=input('enter your chose')
            if a=='1':
                print('you have vote for MEG')
                self.countlist[2]+=1
                #print(self.countlist)
            #if a=='0':
                #continue
        if res=='2':
            print('you  want to vote for TIOLA')
            print('press 1 to comfirm your vote and 0 to go back')
            a=input('enter your chose')
            while a not in ['1']:
                print('error enter either 1 or 0')
                a=input('enter your chose')
            if a=='1':
                print('you have vote for TIOLA')
                self.countlist[3]+=1
                #print(self.countlist)
            #if a=='0':
               # exitorcont(self.vote_page())
         
    def passa_vote(self):
        def exitorcont(func):
            print('''
            press 1 for another services or 0 to exit
            ''')
            res = Validate('Enter your choice',['1','0'],'Enter a valid choice')
            if res=='1':
                func()
            elif res=='0':
                self.login()
        if self.matric not in['160006','160007','160008','160009','160010']:
            print('''
              #############################################################
              ##           WELCOME TO FACULTY OF PURE AND APPLIED SCIENCE VOTING PAGE   ##
              #############################################################
              ''')
            print('PRESIDENT ELECTION')
            print('''PRESS 1 0R 2 TO VOTE FOR THE CANDIDATE OF YOUR CHOOSE
                         1.ESS-GEE
                         2.ROYAL HIGHNESS
            ''')
            res=input('pick your candiadate:')
            while res not in ['1','2']:
                print('error!!! pick either one or two')
                res=input('pick your candiadate:')
            if res=='1':
                print('you vote for ESS-GEE')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1','0']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for ESS-GEE')
                    self.passavote[0]+=1
                    #print(self.passavote)
                if a=='0':
                    exitorcont(self.passa_vote())
            if res=='2':
                print('you vote for ROYAL HIGHNESS')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1','0']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for ROYAL HIGHNESS')
                    self.passavote[1]+=1
                    #print(self.passavote)
                if a=='0':
                    exitorcont(self.passa_vote())
            print(' VICE PRESIDENT ELECTION')
            print('''PRESS 1 0R 2 TO VOTE FOR THE CANDIDATE OF YOUR CHOOSE
                         1.LADY K
                         2.BISOLA
            ''')
            res=input('pick your candiadate:')
            while res not in ['1','2']:
                print('error!!! pick either one or two')
                res=input('pick your candiadate:')
            if res=='1':
                print('you vote for LADY K')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for ')
                    self.passavote[2]+=1
                    #print(self.passavote)
                #if a=='0':
                   # exitorcont(self.passa_vote())
            if res=='2':
                print('you  want to vote for BISOLA')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for BISOLA')
                    self.passavote[3]+=1
                    #print(self.passavote)
                #if a=='0':
                    #exitorcont(self.passa_vote())
        if self.matric not in['160001','160002','160003','160004','160005']:
            print('''
              #############################################################
              ##           WELCOME TO FACULTY OF ENGINEERING AND TECHNOLOGY VOTING PAGE   ##
              #############################################################
              ''')
            print('PRESIDENT ELECTION')
            print('''PRESS 1 0R 2 TO VOTE FOR THE CANDIDATE OF YOUR CHOOSE
                         1.LEON
                         2.JOSH
            ''')
            res=input('pick your candiadate:')
            while res not in ['1','2']:
                print('error!!! pick either one or two')
                res=input('pick your candiadate:')
            if res=='1':
                print('you vote for LEON')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1','0']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for LEON')
                    self.fetdatabase[0]+=1
                    #print(self.fetdatabase)
                if a=='0':
                    exitorcont(self.passa_vote())
            if res=='2':
                print('you vote for  JOSH')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1','0']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for JOSH')
                    self.fetdatabase[1]+=1
                    print( self.fetdatabase)
                if a=='0':
                    exitorcont(self.passa_vote())
            print(' VICE PRESIDENT ELECTION')
            print('''PRESS 1 0R 2 TO VOTE FOR THE CANDIDATE OF YOUR CHOOSE
                         1.GIFT
                         2.AYOOLA
            ''')
            res=input('pick your candiadate:')
            while res not in ['1','2']:
                print('error!!! pick either one or two')
                res=input('pick your candiadate:')
            if res=='1':
                print('you vote for GIFT')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for GIFT')
                    self.fetdatabase[2]+=1
                    #print( self.fetdatabase)
                #if a=='0':
                    #exitorcont(self.passa_vote())
            if res=='2':
                print('you  want to vote for AYOOLA')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1','0']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for AYOOLA')
                    self.fetdatabase[3]+=1
                    #print(self.fetdatabase)
                #if a=='0':
                    #exitorcont( self.fetdatabase())
    def departmentvote(self):
        def exitorcont(func):
            print('''
            press 1 for another services or 0 to exit
            ''')
            res = Validate('Enter your choice',['1','0'],'Enter a valid choice')
            if res=='1':
                func()
            elif res=='0':
                self.login()
        if self.matric not in['160004','160005','160006','160007','160008','160009','160010']:
            print('''
              #############################################################
              ##           WELCOME TO DEPARTMENT PURE AND APPLIED
                                     MATHEMATICS
              ##                  VOTING PAGE   ##
              #############################################################
              ''')
            print('PRESIDENT ELECTION')
            print('''PRESS 1 0R 2 TO VOTE FOR THE CANDIDATE OF YOUR CHOOSE
                         1.YOUNG WOLI
                         2.OFFICIAL
            ''')
            res=input('pick your candiadate:')
            while res not in ['1','2']:
                print('error!!! pick either one or two')
                res=input('pick your candiadate:')
            if res=='1':
                print('you vote for YOUNG WOLI')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1','0']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for YOUNG WOLI')
                    self.department[0]+=1
                    #print(self.department)
                if a=='0':
                    exitorcont(self.departmentvote())
            if res=='2':
                print('you vote for  OFFICIAL')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1','0']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for OFFICIAL')
                    self.department[1]+=1
                    #print( self.department)
                if a=='0':
                    exitorcont(self.departmentvote())
            print(' VICE PRESIDENT ELECTION')
            print('''PRESS 1 0R 2 TO VOTE FOR THE CANDIDATE OF YOUR CHOOSE
                         1.DUNAMIS
                         2.TOYIN
            ''')
            res=input('pick your candiadate:')
            while res not in ['1','2']:
                print('error!!! pick either one or two')
                res=input('pick your candiadate:')
            if res=='1':
                print('you vote for DUNAMIS')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1','0']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for DUNAMIS')
                    self.department[2]+=1
                    #print( self.department)
                #if a=='0':
                    #exitorcont(self.departmentvote())
            if res=='2':
                print('you  want to vote for TOYIN')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1','0']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for TOYIN')
                    self.department[3]+=1
                    #print(self.department)
            #if a=='0':
                #exitorcont( self.fetdatabase())
        if self.matric  not in['160001','160002','160003','160006','160007','160008','160009','160010']:
            print('''
              #############################################################
              ##           WELCOME TO DEPARTMENT PURE AND APPLIED
                                     BIOLOGY
              ##                  VOTING PAGE   ##
              #############################################################
              ''')
            print('PRESIDENT ELECTION')
            print('''PRESS 1 0R 2 TO VOTE FOR THE CANDIDATE OF YOUR CHOOSE
                         1.BRAIN
                         2.EXECELLENCE
            ''')
            res=input('pick your candiadate:')
            while res not in ['1','2']:
                print('error!!! pick either one or two')
                res=input('pick your candiadate:')
            if res=='1':
                print('you vote for BRAIN')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1','0']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
            if a=='1':
                print('you have vote for BRAIN')
                self.department[4]+=1
                #print(self.department)
            if a=='0':
                exitorcont(self.passa_vote())
            if res=='2':
                print('you vote for  EXECELLENCE')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
            while a not in ['1','0']:
                print('error enter either 1 or 0')
                a=input('enter your chose')
            if a=='1':
                print('you have vote for EXCELLENCE')
                self.department[5]+=1
                #print( self.department)
            if a=='0':
                exitorcont(self.passa_vote())
            print(' VICE PRESIDENT ELECTION DEPARMENT OF BIOLOGY')
            print('''PRESS 1 0R 2 TO VOTE FOR THE CANDIDATE OF YOUR CHOOSE
                         1.KENNY
                         2.LADY T
            ''')
            res=input('pick your candiadate:')
            while res not in ['1','2']:
                print('error!!! pick either one or two')
                res=input('pick your candiadate:')
            if res=='1':
                print('you vote for KENNY')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1','0']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for KENNY')
                    self.department[6]+=1
                    #print( self.department)
                #if a=='0':
                    #exitorcont(self.departmentvote())
            if res=='2':
                print('you  want to vote for LADY T')
                print('press 1 to comfirm your vote and 0 to go back')
                a=input('enter your chose')
                while a not in ['1','0']:
                    print('error enter either 1 or 0')
                    a=input('enter your chose')
                if a=='1':
                    print('you have vote for LADY T')
                    self.department[7]+=1
                    #print(self.department)
                #if a=='0':
                    #exitorcont( self.departmentvote())
            
    def anothervote(self):
        self.ballotbox.append(self.matric)
        self.lsgname=['EINSTEIN','ANUOLUWAPO','MEG','TIOLA']
    def electionresult(self):
        print('LSG PRESIDENT ELECTION RESULT')
        print('EINSTEIN=',self.countlist[0],'ANUOLUWAPO=',self.countlist[1])
        print('LSG VICE PRESIDENT ELECTION RESULT')
        print('MEG=',self.countlist[2],'TIOLA=',self.countlist[3])
        print('--------------------------------------------------------')
        print('FACULTY  OF PURE AND APPLIED SCIENCES PRESIDENT ELECTION RESULT')
        print('ESS GEE=',self.passavote[0],'ROYAL HIGHNESS=',self.passavote[1])
        print('FACULTY  OF PURE AND APPLIED SCIENCES VICE PRESIDENT ELECTION RESULT')
        print('LADY K=',self.passavote[2],'BISOLA=',self.passavote[3])
        print('--------------------------------------------------------')
        print('FACULTY  OF ENGINEERING AND TECHNOLOGY PRESIDENT ELECTION RESULT')
        print('LEON=',self.fetdatabase[0],'JOSH=',self.fetdatabase[1])
        print('FACULTY  OF PURE AND APPLIED SCIENCES VICE PRESIDENT ELECTION RESULT')
        print('GIFT=',self.fetdatabase[2],'AYOOLA=',self.fetdatabase[3])
        print('--------------------------------------------------------')
        print('FACULTY  OF PURE AND APPLIED MATHEMATICS PRESIDENT ELECTION RESULT')
        print('YOUNG WOLI=',self.department[0],'OFFICIAL=',self.department[1])
        print('FACULTY  OF PURE AND APPLIED MATHEMATICS VICE PRESIDENT ELECTION RESULT')
        print('DUNAMIS=',self.department[2],'TOYIN=',self.department[3])
        print('--------------------------------------------------------')
        print('FACULTY  OF PURE AND APPLIED BIOLOGY PRESIDENT ELECTION RESULT')
        print('BRAIN=',self.department[4],'EXECELLENCE=',self.department[5])
        print('FACULTY  OF PURE AND APPLIED MATHEMATICS VICE PRESIDENT ELECTION RESULT')
        print('KENNY=',self.department[6],'LADY T=',self.department[7])
    def result(self): 
        fig=plt.figure(figsize=(5,3))
        plt.bar(self.lsgname,self.countlist,color='maroon',width=0.4)
        plt.xlabel('LSG ELECTION CANDIDATE')
        plt.ylabel('NUMBER OF VOTES')
        plt.title('LAUTECH SUG ELECTION RESULT')
        plt.show()
        
d=Voting_system()
choice='1'
while choice!='0':
    d.login()
    d.vote_page()
    d.passa_vote()
    d.departmentvote()
    d.anothervote()
    choice=input('press 1 to continue voting and 0 to conclude voting')
    while choice=='0':
        print
        d.electionresult()
        d.result()
        sys.exit()
# Out:
#               ####################################################
#               ##         WELCOME TO LAUTECH VOTING SYSTEM       ##
#         ####################################################################
#
# kindly enter your matric number:160001
# kindly enter your password:1111
# login successfully
# welcome dear SHAYO to LAUTECH ELECTION PAGE
#
#               #############################################################
#               ##           WELCOME TO LAUTECH SUG ELECTION VOTING PAGE   ##
#               #############################################################
#
# PRESIDENT ELECTION
# PRESS 1 0R 2 TO VOTE FOR THE CANDIDATE OF YOUR CHOOSE
#                      1.ISARINADE AYODEJI FELIX(EINSTEIN)
#                      2.ADEBOYE ANUOLUWAPO(ANUOLUWA)
#
# pick your candiadate:1
# you vote for EINSTEIN
# press 1 to comfirm your vote and 0 to go back
# enter your chose1
# you have vote for EINTEIN
#  VICE PRESIDENT ELECTION
# ...
